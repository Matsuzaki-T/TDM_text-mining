# %%
#module 2.1 efficacy-pmid
import pandas as pd

df_complete = pd.read_csv("../Figure2/Table3.csv",index_col=0)

display(df_complete)
def generate_efficacy_set(df):
    efficacy_set = set()
    #get efficacy columns
    column_list = list(df.columns.values)#list of columns
    efficacy_list = [i for i in column_list if "efficacy" in i]
    df_efficacy = df[efficacy_list]
    #retrieving efficacy from each line in df_efficacy
    for index, efficacy in df_efficacy.iterrows():
       st = set([x for x in efficacy if pd.isnull(x) == False and x != "nan"])
       efficacy_set.update(st)#update
    return efficacy_set

efficacy_set = generate_efficacy_set(df_complete)
print(efficacy_set)
dic_eff_pmid = {}
dic_eff_len = {}

for efficacy in efficacy_set:
    df_screened = df_complete[(df_complete["efficacy1"] == efficacy)|(df_complete["efficacy2"] == efficacy)|(df_complete["efficacy3"] == efficacy)|(df_complete["efficacy4"] == efficacy)|(df_complete["efficacy5"] == efficacy)|(df_complete["efficacy6"] == efficacy)|(df_complete["efficacy7"] == efficacy)|(df_complete["efficacy8"] == efficacy)]
    pmid_set=set()
    for index, line in df_screened.iterrows():
       pmid_set.update(set([f"{x:.0f}" for x in line[11:] if pd.isnull(x) == False and x != "nan"]))
    print("===========")
    print(efficacy)
    print(len(pmid_set))
    print(pmid_set)
    print("===========")
    dic_eff_pmid[efficacy]=pmid_set#key = efficacy, values=PMID set
    dic_eff_len[efficacy]=len(pmid_set)#key = efficacy, values=PMID set

df_efficacy_pmid = pd.DataFrame(dic_eff_pmid.values(),index=dic_eff_pmid.keys())
df_efficacy_len = pd.DataFrame(dic_eff_len.values(),index=dic_eff_pmid.keys(),columns=["Amount"])
df_efficacy_len_pmid = pd.concat([df_efficacy_len,df_efficacy_pmid],axis=1)
display(df_efficacy_len_pmid)
df_efficacy_len_pmid.to_csv("../Figure2/Table4.csv")
# Out:
# ['Pharmaceutic aid (solvent)']
# ['Coenzyme']
# ['Medical gases']
# ['Medical gases']
# ['Supplement (vitamin B2)']
# ['Supplement (vitamin B6)']
# ['Dietary supplement']
# ['Disinfectant (topical)']
# ['Supplement (nutrient)']
# ['Antibacterial', 'Antifungal', 'Emollient', 'Pharmaceutic aid (acidifying', 'flavor', 'lavage)']
# ['Supplement (glycine)']
# ['Supplement (alanine)']
# ['Supplement (amino acid)']
# ['Antidote']
# ['Anti-ulcerative', 'Dietary supplement']
# ['Supplement (serine)']
#     Unnamed: 0     Entry                                               Name  \
# 0            0  D00001\n  Water (JP18/USP)\nPurified water (JP18)\nPurif...
# 1            1  D00002\n  Nadide (JAN/USAN/INN)\nNicotinamide adenine di...
# 2            2  D00003\n                              Oxygen (JP18/USP)\n
# 3            3  D00004\n                      Carbon dioxide (JP18/USP)\n
# 4            4  D00005\n              Flavin adenine dinucleotide (JAN)\n
# 5            5  D00006\n  Pyridoxal phosphate hydrate (JP18)\nPyridoxal ...
# 6            6  D00007\n    Glutamic acid (USP)\nL-Glutamic acid (JP18)\n
# 7            7  D00008\n         Hydrogen peroxide (USP)\nOxydol (JP18)\n
# 8            8  D00009\n  Glucose (JP18)\nPurified glucose (JP18)\nD-Glu...
# 9            9  D00010\n  Acetic acid, glacial (USP)\nAcetic acid (JP18/...
# 10          10  D00011\n                             Glycine (JP18/USP)\n
# 11          11  D00012\n                Alanine (USP)\nL-Alanine (JP18)\n
# 12          12  D00013\n  Aspartic acid (USP/INN)\nL-Aspartic acid (JP18...
# 13          13  D00014\n  Glutathione (JP18)\nGlutathione (reduced type)...
# 14          14  D00015\n  Glutamine (USP)\nL-Glutamine (JP18)\nLevogluta...
# 15          15  D00016\n                  Serine (USP)\nL-Serine (JP18)\n
#
#                             Name(TN)                              Disease  \
# 0             Sterile water (TN)\n                                     \n
# 1                                 \n                                   \n
# 2                                 \n                                   \n
# 3            Carbon dioxide (TN)\n                                     \n
# 4                 Adeflavin (TN)\n                                     \n
# 5               Hipyridoxin (TN)\n                                     \n
# 6                                 \n                                   \n
# 7                   Oxyfull (TN)\n                                     \n
# 8                                 \n                                   \n
# 9                  Acetasol (TN)\n                                     \n
# 10                                \n                                   \n
# 11                                \n                                   \n
# 12                                \n                                   \n
# 13                  Tathion (TN)\n                                     \n
# 14  Endari (TN)\nNutrestore (TN)\n    Sickle cell disease [DS:H00229]\n
# 15                                \n                                   \n
#
#                              0                   1          2  \
# 0   Pharmaceutic aid (solvent)                None       None
# 1                     Coenzyme                None       None
# 2                Medical gases                None       None
# 3                Medical gases                None       None
# 4      Supplement (vitamin B2)                None       None
# 5      Supplement (vitamin B6)                None       None
# 6           Dietary supplement                None       None
# 7       Disinfectant (topical)                None       None
# 8        Supplement (nutrient)                None       None
# 9                Antibacterial          Antifungal  Emollient
# 10        Supplement (glycine)                None       None
# 11        Supplement (alanine)                None       None
# 12     Supplement (amino acid)                None       None
# 13                    Antidote                None       None
# 14             Anti-ulcerative  Dietary supplement       None
# 15         Supplement (serine)                None       None
#
#                                3       4        5
# 0                           None    None     None
# 1                           None    None     None
# 2                           None    None     None
# 3                           None    None     None
# 4                           None    None     None
# 5                           None    None     None
# 6                           None    None     None
# 7                           None    None     None
# 8                           None    None     None
# 9   Pharmaceutic aid (acidifying  flavor  lavage)
# 10                          None    None     None
# 11                          None    None     None
# 12                          None    None     None
# 13                          None    None     None
# 14                          None    None     None
# 15                          None    None     None
